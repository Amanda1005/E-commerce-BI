# %% [markdown]
# # E-Commerce Business Performance Analysis
# ## Notebook 2: RFM Customer Segmentation & A/B Test Simulation
#
# **Goal:**
# - Segment customers using RFM (Recency, Frequency, Monetary) analysis
# - Simulate an A/B test to evaluate promotional strategy effectiveness
# - Generate actionable insights for customer retention and revenue growth
#
# **Dataset:** Online Retail II UCI Dataset (2009–2011)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

plt.style.use('seaborn-v0_8')

df = pd.read_csv('../exports/sales_clean.csv')
print(f"Dataset loaded: {df.shape}")
print(df.columns.tolist())
df.head()
# Out:
# Dataset loaded: (1037427, 12)
# ['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'Price', 'Customer ID', 'Country', 'Revenue', 'Year', 'Month', 'YearMonth']
# /var/folders/v1/xds07jgs4vdbmkv6mszqj2jm0000gn/T/ipykernel_44400/1902883316.py:9: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../exports/sales_clean.csv')
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country  Revenue  Year  \
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom     83.4  2009
# ...
